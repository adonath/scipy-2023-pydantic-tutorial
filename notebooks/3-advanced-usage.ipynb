# %% [markdown]
# # Advanced Usage

# %% [markdown]
# ## Complex Types
#
# We have already seen how to define simple types, such as `int`, `float`, `str`, `bool`, etc. Pydantic also supports more complex types, such as lists, dictionaries, enums, and unions.

# %% [markdown]
# ### Typed Lists and Dictionaries
#
# Typed lists and dictionaries are defined using the `List` and `Dict` generic types. For example, we can define a model with a list of integers as follows:

# %%
class MyData:
    x = List[int]

# %% [markdown]
# ### Enums and Union Types

# %% [markdown]
# ### Datetime Types

# %% [markdown]
# ### Custom Data Types
#
# One of the most powerful features of Pydantic is the ability to define custom data types. This is done by subclassing the `pydantic.BaseModel` class and implementing the `__get_validators__` method. For example, we can define a custom data type that represents a `datetime` object as follows:
#
# ```python

# %% [markdown]
# ### Hierarchical Structures

# %% [markdown]
# ### Private Attributes

# %% [markdown]
# ## Type Validation

# %% [markdown]
# ## Dynamic Model Definition
#
# In rare cases it can be useful to create a Pydantic model dynamically, i.e. without defining the model as a class. This can be done using the `create_model` function. The function takes the name of the model as the first argument, followed by the fields of the model. The fields are defined as a dictionary, where the keys are the names of the fields and the values are the types of the fields. The types can be either Python types or Pydantic models. The function returns a Pydantic model class.
